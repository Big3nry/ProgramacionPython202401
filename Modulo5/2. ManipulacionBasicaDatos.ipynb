# %% [markdown]
# # Manipulación Basica de nuestro DataFrame
# ------------------------
#
# En esta sección aprenderemos a manipular nuestro dataframe con el fin de poder crear automatizaciones sobre nuestros datos

# %%
# Para esta seccion iniciaremos cargando nuestra data

import pandas as pd

df = pd.read_csv('./src/winemag-data-130k-v2.csv')
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
df.shape
# Out:
# (65499, 14)

# %% [markdown]
# ## 1. Manipulación Basica de nuestro DataFrame

# %% [markdown]
# ### 1.1 Seleccion de Columnas

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
# Seleccion de una columna
df['country'].head()
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
# tambien es posible la seleccion de este modo
df.country.head()
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
# Selección de múltiples columnas

# emplearemos una lista
columns_select = ['country','province']
df_subset = df[columns_select]
df_subset.head()
# Out:
#     country           province
# 0     Italy  Sicily & Sardinia
# 1  Portugal              Douro
# 2        US             Oregon
# 3        US           Michigan
# 4        US             Oregon

# %%
# renombrado de columnas

# {'old_colname': 'new_colname'}
df_rename = df.rename(columns={'Unnamed: 0': 'index'})
df_rename.head()
# Out:
#    index   country                                        description  \
# 0      0     Italy  Aromas include tropical fruit, broom, brimston...
# 1      1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2      2        US  Tart and snappy, the flavors of lime flesh and...
# 3      3        US  Pineapple rind, lemon pith and orange blossom ...
# 4      4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
# Eliminando columna
df_drop= df_rename.drop(['index'], axis=1)

df_drop.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
df_rename.head(1)
# Out:
#    index country                                        description  \
# 0      0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
# df_rename= df_rename.drop(['index'], axis=1)
# axis =1 para borrar columnas
df_rename.drop(['index'], axis=1, inplace=True)

# %%
df_rename.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %% [markdown]
# ### 1.2 Aplicando Filtros
#
# Podemos filtrar un dataframe mediante condiciones booleanas sobre columnas

# %%
# condicion -> se encarga de establecer la condicion de Verdad o Falsedad 
condicion = df_rename['country'] == 'Italy'
condicion.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: country, dtype: bool

# %%
# usando la condicion como filtro
df_filter = df_rename[condicion]
df_filter.head(2)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6   Italy  Here's a bright, informal red that opens with ...       Belsito
#
#    points  price           province  region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia      Etna      NaN  Kerin O’Keefe
# 6      87   16.0  Sicily & Sardinia  Vittoria      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                                             title  \
# 0          @kerinokeefe                 Nicosia 2013 Vulkà Bianco  (Etna)
# 6          @kerinokeefe  Terre di Giurfo 2013 Belsito Frappato (Vittoria)
#
#        variety           winery
# 0  White Blend          Nicosia
# 6     Frappato  Terre di Giurfo

# %%
df_filter.shape
# Out:
# (10005, 13)

# %%
# método unique me brinda valores únicos de columna
df_rename.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia'],
#       dtype=object)

# %% [markdown]
# podemos concatenar varias condiciones usando `&` para **AND** ,  `|` para **OR** y `~` como **NOT** o negacion.
#
# Tambien debemos recordar los operadores: `==` , `!=` , `>`, `<` , `>=` , `<=`
#
#
# EL carácter `~` se obtiene mediante ALT+126

# %%
condicion  = (df_rename.country=="Italy") & (df_rename.points>=90)
df_filter2 = df_rename[condicion]
df_filter2.head(2)
# Out:
#     country                                        description  \
# 120   Italy  Slightly backward, particularly given the vint...
# 130   Italy  At the first it was quite muted and subdued, b...
#
#                designation  points  price  province region_1 region_2  \
# 120    Bricco Rocche Prapó      92   70.0  Piedmont   Barolo      NaN
# 130  Bricco Rocche Brunate      91   70.0  Piedmont   Barolo      NaN
#
#     taster_name taster_twitter_handle  \
# 120         NaN                   NaN
# 130         NaN                   NaN
#
#                                             title   variety   winery
# 120    Ceretto 2003 Bricco Rocche Prapó  (Barolo)  Nebbiolo  Ceretto
# 130  Ceretto 2003 Bricco Rocche Brunate  (Barolo)  Nebbiolo  Ceretto

# %%
df_filter2.shape
# Out:
# (3479, 13)

# %%
# método 'unique' -> permite obtener valores unicos de una columna

df_filter2.country.unique()
# Out:
# array(['Italy'], dtype=object)

# %%
# valores únicos de columnas
df_var = df_filter2[['winery','variety']].drop_duplicates(subset=['winery','variety'])
df_var
# Out:
#                      winery            variety
# 120                 Ceretto           Nebbiolo
# 133    Poderi Luigi Einaudi           Nebbiolo
# 135         Giacomo Ascheri           Nebbiolo
# 140            Poderi Colla            Barbera
# 158    Castello di Gabbiano         Sangiovese
# ...                     ...                ...
# 65093                Destro  Nerello Mascalese
# 65203             La Rasina  Sangiovese Grosso
# 65204  Loacker Corte Pavone  Sangiovese Grosso
# 65216  Poggio il Castellare  Sangiovese Grosso
# 65399     Fattoria Nittardi          Red Blend
#
# [1655 rows x 2 columns]

# %% [markdown]
# Para ver más formas de filtrado [ver](https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9)

# %% [markdown]
# ### 1.3 Aplicación de lógicas a nuestros DataFrame
#
# Podemos aplicar lógicas o añadir constantes a nuestros dataFrames.

# %%
df_rename.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
# se pueden realizar operaciones básicas a columnas aplicando lógicas
# Generacion de constantes

df_rename['ajuste_precio'] = 1.2
df_rename.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  ajuste_precio
# 0     White Blend              Nicosia            1.2
# 1  Portuguese Red  Quinta dos Avidagos            1.2
# 2      Pinot Gris            Rainstorm            1.2
# 3        Riesling           St. Julian            1.2
# 4      Pinot Noir         Sweet Cheeks            1.2

# %%
# Operaciones como suma , resta, multiplicacion de columnas son validas
df_rename['new_price'] = df_rename.price * df_rename.ajuste_precio
df_rename.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery  ajuste_precio  new_price
# 0              Nicosia            1.2        NaN
# 1  Quinta dos Avidagos            1.2       18.0
# 2            Rainstorm            1.2       16.8

# %% [markdown]
# podemos usar `apply` en una columna para obtener una nueva columna en función de sus valores

# %%
# df_rename.price.unique()

# Según el precio de la botella de vino aplicar una etiqueta
# Si precio <100 -> Precio accesible
# SI precio >=100 and precio <=500 -> 'vino es moderadamente costoso'
# Si precio >500 -> 'muy caro'

def etiqueta_precio(precio:float):

    if precio<100:
        return 'Precio accesible'
    elif precio <=500 and precio >=100:
        return 'Precio moderadamente alto'
    elif precio >500:
        return 'Precio muy caro'
    else:
        return None

etiqueta_precio(1500)
# Out:
# 'Precio muy caro'

# %%
df_rename['etiqueta_costo'] = df_rename.price.apply(etiqueta_precio)

df_rename.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery  ajuste_precio  new_price  \
# 0     White Blend              Nicosia            1.2        NaN
# 1  Portuguese Red  Quinta dos Avidagos            1.2       18.0
#
#      etiqueta_costo
# 0              None
# 1  Precio accesible

# %%
# aplicando lógicas mediante funciones

def incremento_precio_por_pais(row):
    if row.country == 'Italy':
        return row.price *1.2
    elif row.country == 'Peru':
        return row.price * 1.05
    else:
        return row.price


df_rename['price_by_country'] = df_rename.apply(incremento_precio_por_pais, axis='columns')

# %%
df_rename[['country', 'price', 'price_by_country']].head(20)
# Out:
#       country  price  price_by_country
# 0       Italy    NaN               NaN
# 1    Portugal   15.0              15.0
# 2          US   14.0              14.0
# 3          US   13.0              13.0
# 4          US   65.0              65.0
# 5       Spain   15.0              15.0
# 6       Italy   16.0              19.2
# 7      France   24.0              24.0
# 8     Germany   12.0              12.0
# 9      France   27.0              27.0
# 10         US   19.0              19.0
# 11     France   30.0              30.0
# 12         US   34.0              34.0
# 13      Italy    NaN               NaN
# 14         US   12.0              12.0
# 15    Germany   24.0              24.0
# 16  Argentina   30.0              30.0
# 17  Argentina   13.0              13.0
# 18      Spain   28.0              28.0
# 19         US   32.0              32.0

# %%
condition = df_rename.country == 'Peru'
df_rename[condition][['country', 'price', 'price_by_country']].head(20)
# Out:
#       country  price  price_by_country
# 6565     Peru   14.0             14.70
# 13090    Peru   15.0             15.75
# 14727    Peru   10.0             10.50
# 14732    Peru   10.0             10.50
# 23537    Peru   17.0             17.85
# 37948    Peru   68.0             71.40
# 63521    Peru   20.0             21.00
# 64672    Peru   10.0             10.50

# %%
df_rename.to_excel('./output/wine_review.xlsx', index=False)

# %% [markdown]
# https://www.kaggle.com/code/residentmario/indexing-selecting-assigning
#
#
# https://www.kaggle.com/code/residentmario/summary-functions-and-maps

# %% [markdown]
# # Ejercicios
# ---------------------------------------------

# %%
# 

import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_excel('./src/reactiva.xlsx',sheet_name='TRANSFERENCIAS 2020')

df.head(2)
# Out:
#    ID CODIGO PAIS  CODIGO ENTIDAD  UBIGEO    SNIP      CUI        REGION  \
# 0   1          PE           11476  120127  346548  2307983         JUNIN
# 1   2          PE           11476   90612  213528  2215425  HUANCAVELICA
#
#   PROVINCIA    DISTRITO                                           PROYECTO  \
# 0  HUANCAYO    QUICHUAY  MEJORAMIENTO DE PISTAS Y VEREDAS EN LA CA. LIM...
# 1  HUAYTARA  SAN ISIDRO  MEJORAMIENTO VIAL DEL CERCADO DE LA LOCALIDAD ...
#
#   DISPOSITIVO LEGAL  AMBITO  \
# 0  DU N° 070-2020,   URBANO
# 1  DU N° 070-2020,    RURAL
#
#                                     UNIDAD EJECUTORA  TOTAL EMPLEOS  \
# 0                MUNICIPALIDAD DISTRITAL DE QUICHUAY            121
# 1  MUNICIPALIDAD DISTRITAL DE SAN ISIDRO - HUIRPA...             63
#
#    POBLACION BENEFICIARIA       TIPOLOGIA TIPO MONEDA  MONTO DE INVERSIÓN  \
# 0                    1529  Pista y Vereda         PEN          4105693.00
# 1                     648  Pista y Vereda         PEN          2120069.47
#
#   TIPO MONEDA.1  MONTO DE TRANSFERENCIA 2020        ESTADO
# 0           PEN                      4105693  En Ejecución
# 1           PEN                       413572  En Ejecución

# %%
df.columns
# Out:
# Index(['ID', 'CODIGO PAIS', 'CODIGO ENTIDAD', 'UBIGEO', 'SNIP', 'CUI',
#        'REGION', 'PROVINCIA', 'DISTRITO', 'PROYECTO', 'DISPOSITIVO LEGAL',
#        'AMBITO', 'UNIDAD EJECUTORA', 'TOTAL EMPLEOS', 'POBLACION BENEFICIARIA',
#        'TIPOLOGIA', 'TIPO MONEDA', 'MONTO DE INVERSIÓN', 'TIPO MONEDA.1',
#        'MONTO DE TRANSFERENCIA 2020', 'ESTADO'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                               int64
# CODIGO PAIS                     object
# CODIGO ENTIDAD                   int64
# UBIGEO                           int64
# SNIP                             int64
# CUI                              int64
# REGION                          object
# PROVINCIA                       object
# DISTRITO                        object
# PROYECTO                        object
# DISPOSITIVO LEGAL               object
# AMBITO                          object
# UNIDAD EJECUTORA                object
# TOTAL EMPLEOS                    int64
# POBLACION BENEFICIARIA           int64
# TIPOLOGIA                       object
# TIPO MONEDA                     object
# MONTO DE INVERSIÓN             float64
# TIPO MONEDA.1                   object
# MONTO DE TRANSFERENCIA 2020      int64
# ESTADO                          object
# dtype: object

# %%
# renombrar columnas clave
rename_dicx = {'CODIGO PAIS':'CODIGO_PAIS',
                                   'MONTO DE TRANSFERENCIA 2020':'MONTO_TRANSFERENCIA_2020',
                                 'MONTO DE INVERSIÓN':'MONTO_INVERSION'  }
df.rename(columns=rename_dicx, inplace=True)

df.head(2)
# Para la proviancia HUANCAYO , que tipo de obras se han realizado sobre la provincia y cual ha sido el monto de inversión maximo
# Out:
#    ID CODIGO_PAIS  CODIGO ENTIDAD  UBIGEO    SNIP      CUI        REGION  \
# 0   1          PE           11476  120127  346548  2307983         JUNIN
# 1   2          PE           11476   90612  213528  2215425  HUANCAVELICA
#
#   PROVINCIA    DISTRITO                                           PROYECTO  \
# 0  HUANCAYO    QUICHUAY  MEJORAMIENTO DE PISTAS Y VEREDAS EN LA CA. LIM...
# 1  HUAYTARA  SAN ISIDRO  MEJORAMIENTO VIAL DEL CERCADO DE LA LOCALIDAD ...
#
#   DISPOSITIVO LEGAL  AMBITO  \
# 0  DU N° 070-2020,   URBANO
# 1  DU N° 070-2020,    RURAL
#
#                                     UNIDAD EJECUTORA  TOTAL EMPLEOS  \
# 0                MUNICIPALIDAD DISTRITAL DE QUICHUAY            121
# 1  MUNICIPALIDAD DISTRITAL DE SAN ISIDRO - HUIRPA...             63
#
#    POBLACION BENEFICIARIA       TIPOLOGIA TIPO MONEDA  MONTO_INVERSION  \
# 0                    1529  Pista y Vereda         PEN       4105693.00
# 1                     648  Pista y Vereda         PEN       2120069.47
#
#   TIPO MONEDA.1  MONTO_TRANSFERENCIA_2020        ESTADO
# 0           PEN                   4105693  En Ejecución
# 1           PEN                    413572  En Ejecución

# %%
df_filter = df[df['PROVINCIA']=='HUANCAYO']
df_filter.head()
# Out:
#       ID CODIGO_PAIS  CODIGO ENTIDAD  UBIGEO     SNIP      CUI REGION  \
# 0      1          PE           11476  120127   346548  2307983  JUNIN
# 162  163          PE           11476  120125   215255  2157560  JUNIN
# 192  193          PE           11476  120116  2442321  2442321  JUNIN
# 194  195          PE           11476  120116  2442560  2442560  JUNIN
# 228  229          PE           11476  120107  2452577  2452577  JUNIN
#
#     PROVINCIA      DISTRITO  \
# 0    HUANCAYO      QUICHUAY
# 162  HUANCAYO     PILCOMAYO
# 192  HUANCAYO  HUACRAPUQUIO
# 194  HUANCAYO  HUACRAPUQUIO
# 228  HUANCAYO        CHILCA
#
#                                               PROYECTO DISPOSITIVO LEGAL  \
# 0    MEJORAMIENTO DE PISTAS Y VEREDAS EN LA CA. LIM...  DU N° 070-2020,
# 162  MEJORAMIENTO VIAL DE LA AV. LEONCIO PRADO TRAM...  DU N° 070-2020,
# 192  CREACION DE LOSA DEPORTIVA BARRIO LA BREÑA DEL...  DU N° 070-2020,
# 194  MEJORAMIENTO DE LA TRANSITABILIDAD VEHICULAR Y...  DU N° 070-2020,
# 228  CREACION DE LOSA DE RECREACIÓN MULTIUSOS EN EL...  DU N° 070-2020,
#
#      AMBITO                         UNIDAD EJECUTORA  TOTAL EMPLEOS  \
# 0    URBANO      MUNICIPALIDAD DISTRITAL DE QUICHUAY            121
# 162  URBANO     MUNICIPALIDAD DISTRITAL DE PILCOMAYO            196
# 192  URBANO  MUNICIPALIDAD DISTRITAL DE HUACRAPUQUIO             16
# 194  URBANO  MUNICIPALIDAD DISTRITAL DE HUACRAPUQUIO            165
# 228  URBANO        MUNICIPALIDAD DISTRITAL DE CHILCA             18
#
#      POBLACION BENEFICIARIA            TIPOLOGIA TIPO MONEDA  MONTO_INVERSION  \
# 0                      1529       Pista y Vereda         PEN       4105693.00
# 162                     700       Pista y Vereda         PEN       6701466.11
# 192                     253  Equipamiento Urbano         PEN        524289.77
# 194                     466       Pista y Vereda         PEN       5657312.31
# 228                    6053  Equipamiento Urbano         PEN        594687.77
#
#     TIPO MONEDA.1  MONTO_TRANSFERENCIA_2020        ESTADO
# 0             PEN                   4105693  En Ejecución
# 162           PEN                   3998139  En Ejecución
# 192           PEN                    489731     Concluido
# 194           PEN                   5505675  En Ejecución
# 228           PEN                    479207     Concluido

# %%
df_filter['TIPOLOGIA'].unique()
# Out:
# array(['Pista y Vereda', 'Equipamiento Urbano'], dtype=object)

# %%
df_filter['MONTO_INVERSION'].describe()
# Out:
# count    1.000000e+01
# mean     3.918919e+06
# std      3.621938e+06
# min      5.242898e+05
# 25%      6.840281e+05
# 50%      2.773528e+06
# 75%      6.440428e+06
# max      9.515369e+06
# Name: MONTO_INVERSION, dtype: float64

# %%
df_filter['MONTO_INVERSION'].max()
# Out:
# 9515369.44
